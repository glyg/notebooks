# %% [markdown]
# # La parabole

# %% [markdown]
# C'est la fonction d'équation $f(x) = ax^2 + b$

# %%
def f(x, a=1, b=0):
    y = a * x**2 + b
    return y

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

x = np.linspace(-4, 4, 100)
fig, ax = plt.subplots()

for a in range(1, 4):
    y = f(x, a)
    ax.plot(x, y, label='a = {}'.format(a),
            lw=2, alpha=0.8)

ax.set_xlabel(r'$x$', fontsize=18)
ax.set_ylabel(r'$f(x)$', fontsize=18)
ax.legend()

# %%
y = f(x, a=3, b=15)


fig, ax = plt.subplots()
ax.plot(x, y, label='a = {}'.format(a),
        lw=2, alpha=0.8)

# %% [markdown]
# $\int_0^x \frac{1}{1+x^2}$
